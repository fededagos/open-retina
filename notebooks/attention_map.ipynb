# %%
image_path = "/home/bethge/bkr618/openretina_cache/attn_sparse/epoch024_session_1_ventral1_20200226_b14_t80/all_layers_heads_grid.png"

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg



# Load image
img = mpimg.imread(image_path)

# Display image
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.axis('off')  # remove axes
plt.show()
